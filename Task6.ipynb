# %%
import numpy as np
import pandas as pd

# %%
with open("task6-data/web_clients.csv", encoding="utf-8") as f:
    df = pd.read_csv(f)

# %%
def func(v):
    if v > 25:
        return "Старше 25"
    else:
        return "Младше или равен 25"
df.head(15)["age"].apply(func)
# Out:
# 0               Старше 25
# 1               Старше 25
# 2               Старше 25
# 3               Старше 25
# 4     Младше или равен 25
# 5               Старше 25
# 6               Старше 25
# 7               Старше 25
# 8               Старше 25
# 9               Старше 25
# 10              Старше 25
# 11              Старше 25
# 12    Младше или равен 25
# 13              Старше 25
# 14              Старше 25
# Name: age, dtype: object

# %%
df["age"].apply(func)
# Out:
# 0                Старше 25
# 1                Старше 25
# 2                Старше 25
# 3                Старше 25
# 4      Младше или равен 25
#               ...
# 910    Младше или равен 25
# 911    Младше или равен 25
# 912              Старше 25
# 913    Младше или равен 25
# 914              Старше 25
# Name: age, Length: 915, dtype: object

# %%
df.head(15).query("sex == 'male' and age > 30")
# Out:
#                                     name device_type            browser   sex  \
# 1         Allison  Master. Hudson Trevor      tablet              Opera  male
# 5                    Anderson  Mr. Harry      mobile            Firefox  male
# 7                 Andrews  Mr. Thomas Jr      tablet  Internet Explorer  male
# 9                Artagaveytia  Mr. Ramon      mobile            Firefox  male
# 10                Astor  Col. John Jacob     desktop             Chrome  male
# 14  Barkworth  Mr. Algernon Henry Wilson      laptop             Chrome  male
#
#      age  bill                           region
# 1   48.0   850  Montreal: PQ / Chesterville: ON
# 5   48.0   371                     New York: NY
# 7   39.0   867                      Belfast: NI
# 9   71.0   926              Montevideo: Uruguay
# 10  47.0   100                     New York: NY
# 14  80.0   723                    Hessle: Yorks

# %%
df.query("sex == 'male' and age > 30")
# Out:
#                                           name device_type            browser  \
# 1               Allison  Master. Hudson Trevor      tablet              Opera
# 5                          Anderson  Mr. Harry      mobile            Firefox
# 7                       Andrews  Mr. Thomas Jr      tablet  Internet Explorer
# 9                      Artagaveytia  Mr. Ramon      mobile            Firefox
# 10                      Astor  Col. John Jacob     desktop             Chrome
# ..                                         ...         ...                ...
# 900  Johnston  Master. William Arthur "Willie"     desktop             Chrome
# 902                     Johnston  Mr. Andrew G      tablet  Internet Explorer
# 905                          Jonsson  Mr. Carl     desktop            Firefox
# 909                        Jussila  Mr. Eiriik     desktop            Firefox
# 914          Karlsson  Mr. Julius Konrad Eugen      laptop              Opera
#
# ...
