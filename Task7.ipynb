# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
with open("task6-data/web_clients.csv", encoding="utf-8") as f:
    df = pd.read_csv(f)

# %%
df.head(15).plot(kind="scatter", x="age", y="bill")
# Out:
# <AxesSubplot:xlabel='age', ylabel='bill'>

# %%
df.plot(kind="scatter", x="age", y="bill")
# Out:
# <AxesSubplot:xlabel='age', ylabel='bill'>

# %%
seaborn.regplot(data=df.head(15), x="age", y="bill")
# Out:
# <AxesSubplot:xlabel='age', ylabel='bill'>

# %%
seaborn.regplot(data=df, x="age", y="bill")
# Out:
# <AxesSubplot:xlabel='age', ylabel='bill'>
